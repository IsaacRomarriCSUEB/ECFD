# %% [markdown]
# # Tutorials for ECF

# %% [markdown]
# ##Loading a CSV (comma separted values) File

# %%
#This is a comment and it is ignore by python as long as the line starts with "#"
import pandas as pd # using this library to import a csv file.

california_housing_df = pd.read_csv('/content/sample_data/california_housing_test.csv') #files are imported into a panda object call dataframe.
print("****************************") #print functions writes on the output box below.
california_housing_df.head() # outputs a few rows of california housing file

# Items to notice:
# Columns have a header, later we will used this to refer to entire columns.
# Rows are index with numbers.
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %% [markdown]
# ##Accesing data from a dataframe.

# %%
#Accesing data from a dataframe can be done in several ways. If we want to explore some of the date characteristic we can use the following methods.

california_housing_df.info() # displays the type of object, index ranges, columns names, non-null (items that are consider good values), dtype (type of number)

california_housing_df.describe() # displays different numerical values such as mean, std, min, max, etc.

california_housing_df.tail() # displays the last 5 rows of our data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# ...

# %% [markdown]
# ### Try the following exercises.

# %%
"""
Here is a dataframe exercise using the /content/sample_data/california_housing_train.csv file.

**Task:**

1. Load the `california_housing_test.csv` file into a pandas DataFrame.
2. Display the dataframe information.
3. Get a concise summary of the DataFrame, including the index dtype and column dtypes, non-null values and memory usage.
4. Display descriptive statistics for the numerical columns in the DataFrame.

"""
## your code here ##

# %% [markdown]
# ##Loading file using google

# %%
# File management
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ###Getting the path of a file

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###Find the file in MyDrive
# ![Screen Shot 2025-06-05 at 11.16.55 PM.png](data:image/png;base64,...)
#
# Copy the path of the file.

# %% [markdown]
# ### Load CSV file

# %%
import pandas as pd
import numpy as np
#define the file path.
filepath = "/content/drive/MyDrive/PCAandKMeansLab/Food_Deserts_Data.csv"
food_deserts_df = pd.read_csv(filepath)
